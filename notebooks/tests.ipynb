# %%
import pandas as pd

# %%
df = pd.read_json("../data/raw/arxiv-metadata-oai-snapshot.json", lines=True, chunksize=1000)

# %%
first_chunk = next(df)
first_chunk.head(10)
# Out:
#             id          submitter  \
# 1000  704.1001     Sergey Shadrin
# 1001  704.1002  Michele Cantiello
# 1002  704.1003       Amit Acharya
# 1003  704.1004  Michele Cantiello
# 1004  704.1005       Ben Weinkove
# 1005  704.1006     Andr\'es Navas
# 1006  704.1007          Yong Chen
# 1007  704.1008      Behrang Noohi
# 1008  704.1009      Behrang Noohi
# 1009  704.1010      Behrang Noohi
#
#                                                 authors  \
# 1000                 A. Losev, S. Shadrin, I. Shneiberg
# 1001  M. Cantiello (WSU, and INAF OA-Teramo), G. Rai...
# 1002                                       Amit Acharya
# 1003  M. Cantiello (WSU, and INAF OA-Teramo), G. Rai...
# 1004                         Jian Song and Ben Weinkove
# 1005                      Victor Kleptsyn, Andres Navas
# 1006                            Pan Zhang and Yong Chen
# 1007                                      Behrang Noohi
# 1008                                      Behrang Noohi
# 1009                                      Behrang Noohi
#
#                                                   title  \
# 1000       Tautological relations in Hodge field theory
# 1001              SBF: multi-wavelength data and models
# 1002     On the choice of coarse variables for dynamics
# 1003       Simulating CCD images of elliptical galaxies
# 1004  Constructions of Kahler-Einstein metrics with ...
# 1005  A Denjoy Theorem for commuting circle diffeomo...
# 1006  Transient Dynamics of Sparsely Connected Hopfi...
# 1007                               Explicit HRS-Tilting
# 1008    Lectures on derived and triangulated categories
# 1009  Group actions on algebraic stacks via butterflies
#
#                                                comments  \
# 1000                                           35 pages
# 1001  Presented at From Stars to Galaxies: Building ...
# 1002  To appear in International Journal for Multisc...
# 1003  Presented at From Stars to Galaxies: Building ...
# 1004                                           22 pages
# 1005                                14 pages, 4 figures
# 1006      11 pages, 5 figures. Any comments are favored
# 1007  31 pages, introduction expanded, minor errors ...
# 1008  Lecture notes. To appear in the proceedings vo...
# 1009  Revised version of the preprint previously tit...
#
#                                     journal-ref  \
# 1000  Nucl. Phys. B 786 (2007), no. 3, 267--296
# 1001                                       None
# 1002                                       None
# 1003                                       None
# 1004        Math. Ann. 347 (2010), no. 1, 59-79
# 1005                                       None
# 1006                  Physica A 387, 1009(2008)
# 1007                                       None
# 1008                                       None
# 1009                                       None
#
#                                   doi report-no  \
# 1000  10.1016/j.nuclphysb.2007.07.003      None
# 1001                             None      None
# 1002                             None      None
# 1003                             None      None
# 1004                             None      None
# 1005                             None      None
# 1006      10.1016/j.physa.2007.09.047      None
# 1007                             None      None
# 1008                             None      None
# 1009                             None      None
#
#                               categories  \
# 1000                     math.QA math.AG
# 1001                            astro-ph
# 1002                     nlin.CD math.DS
# 1003                            astro-ph
# 1004                             math.DG
# 1005                             math.DS
# 1006  cond-mat.dis-nn cond-mat.stat-mech
# 1007                     math.RT math.KT
# 1008                     math.KT math.AG
# 1009                     math.AG math.QA
#
#                                                 license  \
# 1000                                               None
# 1001                                               None
# 1002                                               None
# 1003                                               None
# 1004                                               None
# 1005                                               None
# 1006                                               None
# 1007  http://arxiv.org/licenses/nonexclusive-distrib...
# 1008                                               None
# 1009  http://arxiv.org/licenses/nonexclusive-distrib...
#
#                                                abstract  \
# 1000    We propose a Hodge field theory construction...
# 1001    Recent applications have proved that the Sur...
# 1002    Two ideas for the choice of an adequate set ...
# 1003    We introduce a procedure developed by the ``...
# 1004    We show that on Kahler manifolds with negati...
# 1005    We prove that if d is an integer number bigg...
# 1006    Using probabilistic approach, the transient ...
# 1007    For an abelian category $A$ equipped with a ...
# 1008    These notes are meant to provide a rapid int...
# 1009    We introduce an explicit method for studying...
#
#                                                versions update_date  \
# 1000  [{'version': 'v1', 'created': 'Sat, 7 Apr 2007...  2010-10-04
# 1001  [{'version': 'v1', 'created': 'Sat, 7 Apr 2007...  2007-05-23
# 1002  [{'version': 'v1', 'created': 'Sat, 7 Apr 2007...  2007-05-23
# 1003  [{'version': 'v1', 'created': 'Sat, 7 Apr 2007...  2007-05-23
# 1004  [{'version': 'v1', 'created': 'Sat, 7 Apr 2007...  2018-12-14
# 1005  [{'version': 'v1', 'created': 'Sun, 8 Apr 2007...  2007-05-23
# 1006  [{'version': 'v1', 'created': 'Sun, 8 Apr 2007...  2011-11-09
# 1007  [{'version': 'v1', 'created': 'Sun, 8 Apr 2007...  2008-08-28
# 1008  [{'version': 'v1', 'created': 'Sun, 8 Apr 2007...  2007-05-23
# 1009  [{'version': 'v1', 'created': 'Sun, 8 Apr 2007...  2013-09-06
#
#                                          authors_parsed
# 1000  [[Losev, A., ], [Shadrin, S., ], [Shneiberg, I...
# 1001  [[Cantiello, M., , WSU, and INAF OA-Teramo], [...
# 1002                                [[Acharya, Amit, ]]
# 1003  [[Cantiello, M., , WSU, and INAF OA-Teramo], [...
# 1004                [[Song, Jian, ], [Weinkove, Ben, ]]
# 1005          [[Kleptsyn, Victor, ], [Navas, Andres, ]]
# 1006                   [[Zhang, Pan, ], [Chen, Yong, ]]
# 1007                               [[Noohi, Behrang, ]]
# 1008                               [[Noohi, Behrang, ]]
# 1009                               [[Noohi, Behrang, ]]

# %%
first_chunk.columns
# Out:
# Index(['id', 'submitter', 'authors', 'title', 'comments', 'journal-ref', 'doi',
#        'report-no', 'categories', 'license', 'abstract', 'versions',
#        'update_date', 'authors_parsed'],
#       dtype='object')

# %%
import numpy as np

vectors = np.load("../embeddings/vectors.npy")
np.savetxt("../embeddings/vectors.csv", vectors, delimiter=",")

# query = np.load("../embeddings/query.npy")
# np.savetxt("embeddings/query.csv", query, delimiter=",")
